# %%
import os
import numpy as np
import pandas as pd
np.set_printoptions(suppress=True)

# %%
data_dir = "data/data_3"

calendar_file = os.path.join(data_dir, "calendar.csv")
listing_file = os.path.join(data_dir, "listings.csv")
reviews_file = os.path.join(data_dir, "reviews.csv")
sessions_file = os.path.join(data_dir, "sessions.csv")
users_file = os.path.join(data_dir, "users.csv")

# %%
calendar_data = pd.read_csv(calendar_file)
print(calendar_data.shape)
print(calendar_data.isna().sum())
calendar_data
# Out:
# (17363102, 7)
# listing_id               0
# date                     0
# available                0
# price                    0
# adjusted_price    17358884
# minimum_nights         181
# maximum_nights         181
# dtype: int64
#                    listing_id        date available    price adjusted_price  \
# 0                    19902160  2025-05-02         f   $37.00            NaN
# 1                    37075766  2025-11-25         f   $72.00            NaN
# 2         1091268028307262502  2025-05-28         t  $311.00            NaN
# 3          829621911605471263  2025-12-03         t   $36.00            NaN
# 4                     4223187  2025-09-16         f   $86.00            NaN
# ...                       ...         ...       ...      ...            ...
# 17363097              7512340  2025-02-03         f  $110.00            NaN
# 17363098   982306509661111979  2025-07-07         t  $199.00            NaN
# ...

# %%
listing_data = pd.read_csv(listing_file)
print(listing_data.shape)
print(listing_data.isna().sum())
listing_data
# Out:
# (47572, 75)
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
#                                                 ...
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                               12247
# Length: 75, dtype: int64
#                         id                                      listing_url  \
# 0                 18974065             https://www.nocarz.pl/rooms/18974065
# 1      1074535877676155362  https://www.nocarz.pl/rooms/1074535877676155362
# 2       796304692597746009   https://www.nocarz.pl/rooms/796304692597746009
# ...

# %%
reviews_data = pd.read_csv(reviews_file)
print(reviews_data.shape)
print(reviews_data.isna().sum())
reviews_data
# Out:
# (953651, 7)
# listing_id           0
# id                   0
# date                 0
# reviewer_id          0
# reviewer_name        1
# comments            97
# numerical_review     0
# dtype: int64
#                 listing_id                   id        date  reviewer_id  \
# 0                  7276367   905625527223368376  2023-06-03     22414746
# 1                 17331733            483004221  2019-07-07    184308170
# 2                 17175413            146992529  2017-04-24    124877747
# 3       640375760631534421   795522333712347653  2023-01-02    242127230
# 4                 36511631   646941893366267609  2022-06-11    398279659
# ...                    ...                  ...         ...          ...
# 953646            38178115  1128853650172093555  2024-04-06      5405089
# 953647            23068020            702966955  2020-10-23    135176087
# 953648            35312163   894746554863027146  2023-05-19     30621074
# ...

# %%
reviews_data.comments.str.len().max()
reviews_data.iloc[540278].comments
# reviews_data[540278-3:540278+3]
# Out:
# 'To whom it may concern.<br/>Hello, we are now writing this letter to complain about our extremely terrible experience booking with nocarz. To conclude the situation in a word, the host cancelled our reservation for 1 month on the same day for check-in, which caused us a direct economic loss of £400 and made us a huge trouble to find a new place.<br/>We booked our tenancy on September 07 via nocarz to stay with the host named Mila from September 17 to October 17 for 1 month. During our negotiation with the host, which you can find the full record in the appendix, we asked whether we could leave our luggage before the lease term because our previous contract ended on September 13. The host consented generously and directly. She agreed that we could leave our luggage in her garage at 6.30 pm on September 13. In fact, this is the exact reason for us deciding to book this tenancy.<br/>However, on September 13, the host told us that her garage was leaking at the last minute and we could n
# ...

# %%
# np.set_printoptions(suppress=True)
sessions_data = pd.read_csv(sessions_file)
print(sessions_data.shape)
print(sessions_data.isna().sum())
sessions_data
# Out:
# (12880419, 4)
# action             0
# user_id            0
# timestamp          0
# listing_id    953651
# dtype: int64
#                    action   user_id                   timestamp    listing_id
# 0         browse_listings  22414746  2024-11-23T07:03:43.614318           NaN
# 1            view_listing  22414746  2024-11-23T07:47:06.614318  8.622116e+17
# 2            view_listing  22414746  2024-11-23T07:49:25.614318  1.110286e+07
# 3            view_listing  22414746  2024-11-23T08:43:57.614318  1.208480e+18
# 4            view_listing  22414746  2024-11-23T09:01:56.614318  1.705240e+05
# ...                   ...       ...                         ...           ...
# 12880414     view_listing  68849869  2024-11-23T09:50:32.360085  7.035337e+17
# 12880415     view_listing  68849869  2024-11-23T10:40:09.360085  6.491182e+17
# 12880416     view_listing  68849869  2024-11-23T11:23:55.360085  7.846523e+06
# ...

# %%
users_data = pd.read_csv(users_file)
print(users_data.shape)
print(users_data.isna().sum())
users_data
# Out:
# (858830, 7)
# id               0
# name             0
# surname          0
# city             0
# street           0
# street_number    0
# postal_code      0
# dtype: int64
#                id         name   surname                  city        street  \
# 0       203436964       Maciej     Rajch                Puławy    Wybickiego
# 1        40057904       Szymon    Kleban                Poznań         Polna
# 2        71780939   Anna Maria     Zegar                Leszno        Łanowa
# 3       138537725      Juliusz    Trąbka              Radomsko          Nowa
# 4        75310932  Maksymilian     Chłąd   Gorzów Wielkopolski      Piaskowa
# ...           ...          ...       ...                   ...           ...
# 858825   92226519      Dagmara      Słoń  Czechowice-Dziedzice        Krótka
# 858826  496907842       Cezary    Strzyż      Dąbrowa Górnicza     Cmentarna
# 858827  110848776   Anna Maria    Gustaw             Zgorzelec  Konopnickiej
# ...
